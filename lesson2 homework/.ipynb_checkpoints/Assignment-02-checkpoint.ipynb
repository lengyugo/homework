# %% [markdown]
# ## Assignments for Week-02

# %% [markdown]
# In this course, we learnt what's the search problem and what's the machine leanring. In this assignment, we need you do some more practice.

# %% [markdown]
# ### 1. Re-code the house price machine learning
#
# ###### 1. Random Choose Method to get optimal *k* and *b*
# ###### 2.Supervised Direction to get optimal *k* and *b*
# ###### 3.Gradient Descent to get optimal *k* and *b*
# ###### 4. Try different Loss function and learning rate.
#
# For example, you can change the loss function: $Loss = \frac{1}{n} sum({y_i - \hat{y_i}})^2$ to $Loss = \frac{1}{n} sum(|{y_i - \hat{y_i}}|)$
#
# And you can change the learning rate and observe the performance.

# %% [markdown]
# ## 1. Random Choose Method to get optimal k* and *b

# %%
from sklearn.datasets import load_boston
import random
X = load_boston()['data'][:,5]
y = load_boston()['target']

# %%
def price(rm,k,b):
    return k * rm + b

# %%
def loss(y,y_hat):
    return sum((y_i - y_hat_i)** 2 for y_i,y_hat_i in zip(list(y),list(y_hat))) / len(list(y))

# %%
try_times = 2000
min_loss = float('inf')

best_k,best_b = None,Non
for i in range(try_times):
    current_k = random.random() * 200 - 100
    current_b = random.random() * 200 - 100
    price_k_and_b = [price(r,current_k,current_b)for r in X]
    current_loss = loss(y,price_k_and_b)
    
    if current_loss < min_loss:
        min_loss = current_loss
        best_k,best_b = current_k,current_b
        print('when times is :{},get best_k: {} best_b: {},and the loss is {}'.
              format(i,best_k,best_b,current_loss))
# Out:
# when times is :0,get best_k: 31.50713736461867 best_b: -42.21809464778807,and the loss is 18049.137370353015
# when times is :2,get best_k: 25.922548262364202 best_b: -21.4952242370007,and the loss is 14316.808903639781
# when times is :10,get best_k: 8.684055880526302 best_b: 16.447799685034738,and the loss is 2395.0743665913756
# when times is :29,get best_k: 13.250881902462666 best_b: -30.999865587474076,and the loss is 936.8029419004519
# when times is :86,get best_k: 6.455377897416881 best_b: 6.386182118637862,and the loss is 643.5381118923999
# when times is :98,get best_k: -0.8050530815884542 best_b: 36.78854227628378,and the loss is 176.53091638022178
# when times is :122,get best_k: -0.6542487970478561 best_b: 28.452128998941618,and the loss is 93.76594074259683
# when times is :210,get best_k: 16.78965071498955 best_b: -79.56909072978232,and the loss is 84.37967344619949
# ...

# %% [markdown]
# ## 2.Supervised Direction to get optimal k* and *b

# %%
try_times = 2000
min_loss = float('inf')
best_k = random.random() * 200 -150
best_b = random.random() * 200 -150
direction = [(+1,-1),(+1,+1),(-1,-1),(-1,+1)]

next_direction = random.choice(direction)
update_times = 0
scaler = 0.1

for i in range(try_times):
    k_direction,b_direction = next_direction
    current_k,current_b = best_k + k_direction * scaler,best_b + b_direction * scaler 
    
    price_k_and_b = [price(r,current_k,current_b)for r in X]
    current_loss = loss(y,price_k_and_b)
    
    if current_loss < min_loss:
        min_loss = current_loss
        
        best_k,best_b = current_k,current_b
        
        next_direction = next_direction
        update_times += 1
        
        if update_times % 10 == 0:
            print('when times is :{},get best_k: {} best_b: {},and the loss is {}'.
                  format(i,best_k,best_b,current_loss))
    else:
        next_direction = random.choice(direction)
# Out:
# when times is :10,get best_k: -20.84534747267668 best_b: 1.5679485307603789,and the loss is 23580.42979691837
# when times is :20,get best_k: -19.845347472676664 best_b: 2.5679485307603795,and the loss is 21390.383103167624
# when times is :30,get best_k: -18.84534747267665 best_b: 3.5679485307603804,and the loss is 19307.453596163934
# when times is :40,get best_k: -17.845347472676636 best_b: 4.567948530760379,and the loss is 17331.641275907277
# when times is :50,get best_k: -16.84534747267662 best_b: 5.5679485307603755,and the loss is 15462.946142397624
# when times is :60,get best_k: -15.845347472676611 best_b: 6.567948530760372,and the loss is 13701.368195635048
# when times is :70,get best_k: -14.845347472676615 best_b: 7.567948530760368,and the loss is 12046.9074356195
# when times is :80,get best_k: -13.845347472676618 best_b: 8.567948530760365,and the loss is 10499.56386235102
# ...

# %% [markdown]
# ## 3.Gradient Descent to get optimal k* and *b

# %%
def partial_k(x,y,y_hat):
    n = len(y)
    
    gradient = 0
    for x_i,y_i,y_hat_i in zip(list(x),list(y),list(y_hat)):
        gradient += (y_i - y_hat_i)* x_i
        
    return -2/n * gradient

def partial_b(x,y,y_hat):
    n = len(y)
    
    gradient = 0
    for x_i,y_i,y_hat_i in zip(list(x),list(y),list(y_hat)):
        gradient += (y_i - y_hat_i)
        
    return -2/n * gradient

# %%
try_times = 2000
min_loss = float('inf')

current_k = random.random() * 200 - 100
current_b = random.random() * 200 - 100

update_times = 0
learn_rate = 1e-04

for i in range(try_times):

    price_k_and_b = [price(r,current_k,current_b)for r in X]
    current_loss = loss(y,price_k_and_b)
    
    if current_loss < min_loss:
        
        min_loss = current_loss
    
        update_times += 1
        
        if update_times % 50 == 0:
            print('when times is :{},get best_k: {} best_b: {},and the loss is {}'.
                  format(i,current_k,current_b,current_loss))
    g_greadint = partial_k(X,y,price_k_and_b)
    k_greadint = partial_b(X,y,price_k_and_b)
    
    current_k = current_k + (-1 * g_greadint * learn_rate)
    current_b = current_b + (-1 * k_greadint * learn_rate)
# Out:
# when times is :49,get best_k: -59.785892940401126 best_b: -40.627477238306156,and the loss is 195008.57041331797
# when times is :99,get best_k: -36.80073724151234 best_b: -37.014680073374066,and the loss is 85661.89365664983
# when times is :149,get best_k: -21.56887836933287 best_b: -34.62074040595528,and the loss is 37642.709715518045
# when times is :199,get best_k: -11.474982873099332 best_b: -33.03451455867584,and the loss is 16555.264746289067
# when times is :249,get best_k: -4.785918670199855 best_b: -31.983545381720194,and the loss is 7294.792163370949
# when times is :299,get best_k: -0.3531718627595348 best_b: -31.287280667744664,and the loss is 3228.0902453410026
# when times is :349,get best_k: 2.5843560176223717 best_b: -30.826071878993982,and the loss is 1442.213278820657
# when times is :399,get best_k: 4.5310305512613835 best_b: -30.520630189275302,and the loss is 657.9520545246661
# ...

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1562414412237&di=8377c38d7b50c6f8d45b92ccc78dc1e7&imgtype=0&src=http%3A%2F%2Fmmbiz.qpic.cn%2Fmmbiz_jpg%2FlSyiavfm6wPgQDuDYa42IMgSkLOcPJU91RbkMibGy7VHLrhhNVLibTYk1iaLcmXKTdHc4icTDVia59QFXwqpW8cLflaw%2F640%3Fwx_fmt%3Djpeg)

# %% [markdown]
# ## 2. Answer following questions:
#
#
# ###### 1. Why do we need machine learning methods instead of creating a complicated formula?

# %% [markdown]
# Ans:因为有很多复杂的问题不能创造出一个公式来解决问题，或者很难找到一个符合的公式。

# %% [markdown]
# ###### 2.  Wha't's the disadvantages of `the 1st Random Choosen` methods in our course?

# %% [markdown]
# Ans:1.加大了计算数据量，浪费资源。2.完全随机的尝试增加了很多不必要的工作。

# %% [markdown]
# ###### 3. Is the `2nd method supervised direction` better than 1st one?  What's the disadvantages of `the 2nd supversied directin` method?

# %% [markdown]
# Ans:第二种方法要比第一种好很多，在同样的尝试次数下，第二种方法可以达到更好的效果。
# 我们希望损失函数越小越好，第二种方式不能够达到我们的预期。

# %% [markdown]
# ###### 4. Why do we use `Derivative / Gredient` to fit a target function?

# %% [markdown]
# Ans:梯度的几何意义就是函数变化最快的方向，我们沿着梯度的反方向，梯度减少的最快，这样可以找到函数的最小值。而对于我们这个问题来说，找出梯度的方向，然后沿着这个方向去变化，是最快的找到符合我们预期的方法。

# %% [markdown]
# ###### 5. In the words 'Gredient Descent', what's the `Gredient` and what's the `Descent`?

# %% [markdown]
# Ans:梯度二元函数中就是对参数求偏导数，在多元函数中就是把求得的各个参数的偏导数以向量的形式表示出来就是梯度。
# 而下降的意思是，对于一个多维的函数来说，我们不可能一下子找到损失函数的最小值，我们可以先一个维度上找到损失函数的最小值，然后一步一步的的找到整个函数的损失函数的最小值。

# %% [markdown]
# ###### 6. What's the advantages of `the 3rd gradient descent method` compared to the previous methods?

# %% [markdown]
# Ans:梯度下降保证了我们的尝试一定是在正确的方向上收敛的，可以得出比较好的效果。

# %% [markdown]
# ###### 7. Using the simple words to describe: What's the machine leanring.

# %% [markdown]
# Ans:机器学习就是一种，通过不断地输入数据量，模型参数会逐渐朝着我们想要的方向变化的一种方式。

# %% [markdown]
# ## 3. Finish the search problem

# %% [markdown]
# Please using the search policy to implement an agent. This agent receives two input, one is @param start station and the other is @param destination. Your agent should give the optimal route based on Beijing Subway system.

# %% [markdown]
# > Deadline: 2019-July-13
#
# >Submit: Submit the source code and result to github.

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1562414356407&di=b57814aafd215bb8b8d9d8cd37c573d6&imgtype=0&src=http%3A%2F%2Fcli.clewm.net%2Ffile%2F2015%2F03%2F24%2F174ed60082b8422ac0636cfd3efb9e7f.jpg)

# %% [markdown]
# #### Dataflow:

# %% [markdown]
# ##### 1.	Get data from web page.
#
# > a.	Get web page source from: https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81/408485
#
# > b.	You may need @package **requests**[https://2.python-requests.org/en/master/] page to get the response via url
#
# > c.	You may need save the page source to file system.
#
# > d.	The target of this step is to get station information of all the subway lines;
#
# > e.	You may need install @package beautiful soup[https://www.crummy.com/software/BeautifulSoup/bs4/doc/]  to get the url information, or just use > Regular Expression to get the url.  Our recommendation is that using the Regular Expression and BeautiflSoup both.
#
# > f.	You may need BFS to get all the related page url from one url.
# Question: Why do we use BFS to traverse web page (or someone said, build a web spider)?  Can DFS do this job? which is better?

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
url = 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81/408485'
html = urlopen(url)

# %%
bsObj = BeautifulSoup(html.read())

# %%
text = re.compile(r'北京地铁\w+线')

# %%
station_url = bsObj.find_all('a',href=re.compile(r'(/item/(%[A-Z0-9]+)+)'),text=text)

# %%
station_url[0].get('href')
# Out:
# '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%811%E5%8F%B7%E7%BA%BF'

# %%
station_web = {}
for i in station_url:
    #print(i)
    url = 'https://baike.baidu.com' + i.get('href')
    
    name = i.text
    station_web[name] = url

# %%
station_web
# Out:
# {'北京地铁1号线': 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%811%E5%8F%B7%E7%BA%BF',
#  '北京地铁13号线': 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8113%E5%8F%B7%E7%BA%BF',
#  '北京地铁八通线': 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%85%AB%E9%80%9A%E7%BA%BF',
#  '北京地铁5号线': 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%815%E5%8F%B7%E7%BA%BF',
#  '北京地铁8号线': 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%818%E5%8F%B7%E7%BA%BF',
#  '北京地铁10号线': 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8110%E5%8F%B7%E7%BA%BF',
#  '北京地铁机场线': 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%9C%BA%E5%9C%BA%E7%BA%BF',
#  '北京地铁4号线': 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%814%E5%8F%B7%E7%BA%BF',
#  '北京地铁15号线': 'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8115%E5%8F%B7%E7%BA%BF',
# ...

# %%
import pandas as pd

# %%
city_subway_1 = {}

# %%
city_subway = {}

# %%
#fp = open('北京地铁1号线.txt','w',encoding='utf-8')
#city_subway_1 = {}
def subway_station_1(subway,url):
    
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        if i.find().text == subway + "首末车时刻表":
            #print(i)
            station_list = []
            for tr in i.find_all('tr'):
                for td in tr.find_all('td'):
                    #print(td.get('colspan'))
                    if (td.get('colspan') == "1" and td.get('rowspan') == "1"):
                        #print(td)
                        station = td.get_text()
                        #print(station)
                        station_list.append(station)
                        city_subway_1[subway] = station_list
                        city_subway[subway] = station_list
    return city_subway,city_subway_1

# %%
subway_station_1('北京地铁1号线',station_web['北京地铁1号线'])
# Out:
# ({'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
#    '复兴门',
#    '西单',
#    '天安门西',
#    '天安门东',
#    '王府井',
#    '东单',
#    '建国门',
#    '永安里',
#    '国贸',
#    '大望路',
#    '四惠',
#    '四惠东']},
#  {'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
#    '复兴门',
#    '西单',
#    '天安门西',
#    '天安门东',
#    '王府井',
#    '东单',
#    '建国门',
#    '永安里',
#    '国贸',
#    '大望路',
#    '四惠',
#    '四惠东']})

# %%
#city_subway_2 = {}
def subway_station_2(subway,url):
    
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        if i.find().text == subway + "首末车时间表":
            #print(i)
            station_list = []
            names_list = []
            for tr in i.find_all('tr'):
                #2号线车站名称
            
                if tr.find_all('th'):
                    for th in tr.find_all('th'):
                        names = th.get_text()
                        if names not in ['车站名称','敷设方式','站厅形式','站台形式','开门方向','参考资料','','外环（西直门-复兴门-东直门-西直门）\n',
                                        '内环（积水潭-东直门-复兴门-积水潭）','【注】']:
                            #print(names)
                            station_list.append(names)
                            city_subway_1[subway] = station_list
                            city_subway[subway] = station_list
    city_subway_1[subway] += ['西直门']
    city_subway[subway] += ['西直门']         
    return city_subway,city_subway_1

# %%
subway_station_2('北京地铁2号线',station_web['北京地铁2号线'])
# Out:
# ({'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
#    '复兴门',
#    '西单',
#    '天安门西',
#    '天安门东',
#    '王府井',
#    '东单',
#    '建国门',
#    '永安里',
#    '国贸',
#    '大望路',
#    '四惠',
#    '四惠东'],
#   '北京地铁2号线': ['西直门',
#    '积水潭',
#    '鼓楼大街',
#    '安定门',
#    '雍和宫',
#    '东直门',
#    '东四十条',
#    '朝阳门',
#    '建国门',
#    '北京站',
#    '崇文门',
#    '前门',
#    '和平门',
#    '宣武门',
#    '长椿街',
#    '复兴门',
#    '阜成门',
#    '车公庄',
#    '西直门',
#    '西直门']},
#  {'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
#    '复兴门',
#    '西单',
#    '天安门西',
#    '天安门东',
#    '王府井',
#    '东单',
#    '建国门',
#    '永安里',
#    '国贸',
#    '大望路',
#    '四惠',
#    '四惠东'],
#   '北京地铁2号线': ['西直门',
#    '积水潭',
#    '鼓楼大街',
#    '安定门',
#    '雍和宫',
#    '东直门',
#    '东四十条',
#    '朝阳门',
#    '建国门',
#    '北京站',
#    '崇文门',
#    '前门',
# ...

# %%
#city_subway_4 = {}
def subway_station_4(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        if i.find().text == subway + "车站列表":
            for tr in i.find_all('tr'):
            #print(i)
                for td in tr.find_all('td'):
                    #print(td)
                    if td.get('colspan') == "2" and td.get('rowspan') == "1":
                        #print(td)
                        station = td.get_text().replace('\n','')
                        if station != "北京南站":
                            station = station.split('站')[0]
                        #print(station.split('站')[0])
                        #if station not in ['车站','首班车','末班车','\d\d:\d\d','--']:
                        #print(station)
                        station_list.append(station)
                        city_subway_1[subway] = station_list
                        city_subway[subway] = station_list
    return city_subway,city_subway_1

# %%
subway_station_4('北京地铁4号线',station_web['北京地铁4号线'])
# Out:
# ({'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
#    '复兴门',
#    '西单',
#    '天安门西',
#    '天安门东',
#    '王府井',
#    '东单',
#    '建国门',
#    '永安里',
#    '国贸',
#    '大望路',
#    '四惠',
#    '四惠东'],
#   '北京地铁2号线': ['西直门',
#    '积水潭',
#    '鼓楼大街',
#    '安定门',
#    '雍和宫',
#    '东直门',
#    '东四十条',
#    '朝阳门',
#    '建国门',
#    '北京站',
#    '崇文门',
#    '前门',
#    '和平门',
#    '宣武门',
#    '长椿街',
#    '复兴门',
#    '阜成门',
#    '车公庄',
#    '西直门',
#    '西直门'],
#   '北京地铁4号线': ['公益西桥',
#    '角门西',
#    '马家堡',
#    '北京南站',
#    '陶然亭',
#    '菜市口',
#    '宣武门',
#    '西单',
#    '灵境胡同',
#    '西四',
#    '平安里',
#    '新街口',
#    '西直门',
#    '动物园',
#    '国家图书馆',
#    '魏公村',
#    '人民大学',
#    '海淀黄庄',
#    '中关村',
#    '北京大学东门',
#    '圆明园',
#    '西苑',
#    '北宫门',
#    '安河桥北']},
#  {'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
# ...

# %%
#city_subway_5 = {}
def subway_station_5(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        if i.find().text == subway + "车站列表":
            for tr in i.find_all('tr'):
            #print(i)
                for td in tr.find_all('td'):
                    #print(td)
                    if td.get('colspan') == "2" and td.get('rowspan') == "1":
                        #print(td)
                        station = td.get_text().replace('\n','').split('站')[0]
                        if station not in ['平西府', '平坊', '东沙各庄','太阳城', '马坊','大柳树','小汤山']:
                            station_list.append(station)
                            city_subway_1[subway] = station_list
                            city_subway[subway] = station_list         
                                             
    return city_subway,city_subway_1

# %%
subway_station_5('北京地铁5号线',station_web['北京地铁5号线'])
# Out:
# ({'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
#    '复兴门',
#    '西单',
#    '天安门西',
#    '天安门东',
#    '王府井',
#    '东单',
#    '建国门',
#    '永安里',
#    '国贸',
#    '大望路',
#    '四惠',
#    '四惠东'],
#   '北京地铁2号线': ['西直门',
#    '积水潭',
#    '鼓楼大街',
#    '安定门',
#    '雍和宫',
#    '东直门',
#    '东四十条',
#    '朝阳门',
#    '建国门',
#    '北京站',
#    '崇文门',
#    '前门',
#    '和平门',
#    '宣武门',
#    '长椿街',
#    '复兴门',
#    '阜成门',
#    '车公庄',
#    '西直门',
#    '西直门'],
#   '北京地铁4号线': ['公益西桥',
#    '角门西',
#    '马家堡',
#    '北京南站',
#    '陶然亭',
#    '菜市口',
#    '宣武门',
#    '西单',
#    '灵境胡同',
#    '西四',
#    '平安里',
#    '新街口',
#    '西直门',
#    '动物园',
#    '国家图书馆',
#    '魏公村',
#    '人民大学',
#    '海淀黄庄',
#    '中关村',
#    '北京大学东门',
#    '圆明园',
#    '西苑',
#    '北宫门',
#    '安河桥北'],
#   '北京地铁5号线': ['宋家庄',
#    '刘家窑',
#    '蒲黄榆',
#    '天坛东门',
#    '磁器口',
#    '崇文门',
#    '东单',
#    '灯市口',
#    '东四',
#    '张自忠路',
#    '北新桥',
# ...

# %%
#city_subway_6 = {}
def subway_station_6(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        if i.find().text == subway + "车站列表":
            for tr in i.find_all('tr'):
            #print(i)
                for td in tr.find_all('td'):
                    #print(td)
                    if td.get('width') == "89":
                        #print(td)
                        station = td.get_text().replace('\n','').split('站')[0]
                         #print(station)
                        if station not in ['西延','2018年12月30日[52]\xa0','暂缓开通','一期','二期','2018年12月30日','通运门','二里沟']:
                       
                            station_list.append(station)
                            city_subway_1[subway] = station_list
                            city_subway[subway] = station_list
    return city_subway,city_subway_1

# %%
subway_station_6('北京地铁6号线',station_web['北京地铁6号线'])
# Out:
# ({'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
#    '复兴门',
#    '西单',
#    '天安门西',
#    '天安门东',
#    '王府井',
#    '东单',
#    '建国门',
#    '永安里',
#    '国贸',
#    '大望路',
#    '四惠',
#    '四惠东'],
#   '北京地铁2号线': ['西直门',
#    '积水潭',
#    '鼓楼大街',
#    '安定门',
#    '雍和宫',
#    '东直门',
#    '东四十条',
#    '朝阳门',
#    '建国门',
#    '北京站',
#    '崇文门',
#    '前门',
#    '和平门',
#    '宣武门',
#    '长椿街',
#    '复兴门',
#    '阜成门',
#    '车公庄',
#    '西直门',
#    '西直门'],
#   '北京地铁4号线': ['公益西桥',
#    '角门西',
#    '马家堡',
#    '北京南站',
#    '陶然亭',
#    '菜市口',
#    '宣武门',
#    '西单',
#    '灵境胡同',
#    '西四',
#    '平安里',
#    '新街口',
#    '西直门',
#    '动物园',
#    '国家图书馆',
#    '魏公村',
#    '人民大学',
#    '海淀黄庄',
#    '中关村',
#    '北京大学东门',
#    '圆明园',
#    '西苑',
#    '北宫门',
#    '安河桥北'],
#   '北京地铁5号线': ['宋家庄',
#    '刘家窑',
#    '蒲黄榆',
#    '天坛东门',
#    '磁器口',
#    '崇文门',
#    '东单',
#    '灯市口',
#    '东四',
#    '张自忠路',
#    '北新桥',
# ...

# %%
#city_subway_7 = {}
def subway_station_7(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        if i.find().text == subway + "车站列表":
            for tr in i.find_all('tr'):
            #print(i)
                for td in tr.find_all('td'):
                    #print(td)
                    if td.get('width') == "108":
                        #print(td)
                        station = td.get_text().replace('\n','')
                        if station != "北京西站":
                            station = station.split('站')[0]
                         #print(station)
                        #if station not in ['西延','2018年12月30日[52]\xa0','暂缓开通','一期','二期','2018年12月30日']:
                       
                        station_list.append(station)
                        city_subway_1[subway] = station_list
    return city_subway_1

# %%
subway_station_7('北京地铁7号线',station_web['北京地铁7号线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
#city_subway_8 = {}
def subway_station_8(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        if i.find().text == subway + "车站列表":
            for tr in i.find_all('tr'):
            #print(i)
                for td in tr.find_all('td'):
                    #print(td)
                    if td.get('colspan') == "2" and td.get('rowspan') == "1":
                        #print(td)
                        station = td.get_text().replace('\n','')
                        if station in ['金鱼胡同站[3]\xa0','王府井站','前门站']:continue
                            #station = '金鱼胡同站'
                        #if station != "北京南站":
                        station = station.split('站')[0]
                        station_list.append(station)
                        city_subway_1[subway] = station_list
    return city_subway_1

# %%
subway_station_8('北京地铁8号线',station_web['北京地铁8号线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
#city_subway_9 = {}
def subway_station_9(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        if i.find().text == subway + "车站列表":
            for tr in i.find_all('tr'):
            #print(i)
                for td in tr.find_all('td'):
                    #print(td)
                    if td.get('width') == "72" and td.get('height') == "27":
                        #print(td)
                        station = td.get_text().replace('\n','')
                        if station != "北京西站":
                            station = station.split('站')[0]
                        station_list.append(station)
                        city_subway_1[subway] = station_list
    return city_subway_1

# %%
subway_station_9('北京地铁9号线',station_web['北京地铁9号线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
#city_subway_10 = {}
def subway_station_10(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a = subway + "车站列表"
        #print(i.find().text.strip() == a)
        #print(a)
        if i.find().text.strip() == a:
            #print(i) 
            for tr in i.find_all('tr'):
                #print(tr)
                for td in tr.find_all('td'):
                    #print(td)
                    if td.get('width') == "84":
                        #print(td)
                        station = td.get_text().replace('\n','')
                        if station != '丰台站':
                            station = station.split('站')[0]
                        station_list.append(station)
                        city_subway_1[subway] = station_list
                        city_subway[subway] = station_list
    return city_subway,city_subway_1

# %%
subway_station_10('北京地铁10号线',station_web['北京地铁10号线'])
# Out:
# ({'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
#    '复兴门',
#    '西单',
#    '天安门西',
#    '天安门东',
#    '王府井',
#    '东单',
#    '建国门',
#    '永安里',
#    '国贸',
#    '大望路',
#    '四惠',
#    '四惠东'],
#   '北京地铁2号线': ['西直门',
#    '积水潭',
#    '鼓楼大街',
#    '安定门',
#    '雍和宫',
#    '东直门',
#    '东四十条',
#    '朝阳门',
#    '建国门',
#    '北京站',
#    '崇文门',
#    '前门',
#    '和平门',
#    '宣武门',
#    '长椿街',
#    '复兴门',
#    '阜成门',
#    '车公庄',
#    '西直门',
#    '西直门'],
#   '北京地铁4号线': ['公益西桥',
#    '角门西',
#    '马家堡',
#    '北京南站',
#    '陶然亭',
#    '菜市口',
#    '宣武门',
#    '西单',
#    '灵境胡同',
#    '西四',
#    '平安里',
#    '新街口',
#    '西直门',
#    '动物园',
#    '国家图书馆',
#    '魏公村',
#    '人民大学',
#    '海淀黄庄',
#    '中关村',
#    '北京大学东门',
#    '圆明园',
#    '西苑',
#    '北宫门',
#    '安河桥北'],
#   '北京地铁5号线': ['宋家庄',
#    '刘家窑',
#    '蒲黄榆',
#    '天坛东门',
#    '磁器口',
#    '崇文门',
#    '东单',
#    '灯市口',
#    '东四',
#    '张自忠路',
#    '北新桥',
# ...

# %%
#city_subway_13 = {}
def subway_station_13(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a = subway[4:] + "首末车时刻表"
#         print(i.find().text.strip() == a)
#         print(a)
        if i.find().text.strip() == a:
#             print(i) 
            for tr in i.find_all('tr'):
                #print(tr)
                if tr.find_all('th'):
                    for th in tr.find_all('th'):
                        #print(th)
                        names = th.get_text()
                        if names not in ['车站名称','敷设方式','站厅形式','开门方向', '全程末班车时间','半程末班车时间','首车时间'
                                         ,'清华东路西口','明光桥西']:
                            #if station != "北京南站":
                            names = names.split('站')[0]
                            #print(names)
                            station_list.append(names)
                            city_subway_1[subway] = station_list
               
    return city_subway_1

# %%
subway_station_13('北京地铁13号线',station_web['北京地铁13号线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
def subway_station_14(subway,url):
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a1 = subway[4:] +"东段（含中段）" +"首末车时刻表"
        a2 = subway[4:] +"（西段）" +"首末车时刻表"
        #print(i.find().text.strip() == a)
        #print(a)
        if i.find().text.strip() == a1 or i.find().text.strip() == a2:
            #print(i) 
            for tr in i.find_all('tr'):
                 #print(tr)
                if tr.find_all('th'):
                    for th in tr.find_all('th'):
                        #print(th)
                        if th.get('colspan') != '2' and th.get('colspan') != '3':
                            names = th.get_text()
                            if names not in ['车站名称','敷设方式','站厅形式','开门方向', '全程末班车时间','半程末班车时间','首车时间']:
                                if names != "北京南站":
                                    names = names.split('站')[0]
                                #print(names)
                                station_list.append(names)
                                city_subway_1[subway] = station_list
               
    return city_subway_1

# %%
subway_station_14('北京地铁14号线',station_web['北京地铁14号线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
def subway_station_15(subway,url):
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a = subway + "首末车时刻表"
        if i.find().text.strip() == a:#or i.find().text.strip() == a2:
            #print(i) 
            for tr in i.find_all('tr'):
                 #print(tr)
                if tr.find_all('th'):
                    for th in tr.find_all('th'):
                        #print(th)
                        if th.get('colspan') != '2' and th.get('colspan') != '3':
                            names = th.get_text().split('站')[0]
                            if names not in ['车','敷设方式','站厅形式','开门方向', '全程末班车时间','半程末班车时间','首车时间']:
                                #print(names)
                                station_list.append(names)
                                city_subway_1[subway] = station_list
                                city_subway[subway] = station_list
               
    return city_subway,city_subway_1

# %%
subway_station_15('北京地铁15号线',station_web['北京地铁15号线'])
# Out:
# ({'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
#    '复兴门',
#    '西单',
#    '天安门西',
#    '天安门东',
#    '王府井',
#    '东单',
#    '建国门',
#    '永安里',
#    '国贸',
#    '大望路',
#    '四惠',
#    '四惠东'],
#   '北京地铁2号线': ['西直门',
#    '积水潭',
#    '鼓楼大街',
#    '安定门',
#    '雍和宫',
#    '东直门',
#    '东四十条',
#    '朝阳门',
#    '建国门',
#    '北京站',
#    '崇文门',
#    '前门',
#    '和平门',
#    '宣武门',
#    '长椿街',
#    '复兴门',
#    '阜成门',
#    '车公庄',
#    '西直门',
#    '西直门'],
#   '北京地铁4号线': ['公益西桥',
#    '角门西',
#    '马家堡',
#    '北京南站',
#    '陶然亭',
#    '菜市口',
#    '宣武门',
#    '西单',
#    '灵境胡同',
#    '西四',
#    '平安里',
#    '新街口',
#    '西直门',
#    '动物园',
#    '国家图书馆',
#    '魏公村',
#    '人民大学',
#    '海淀黄庄',
#    '中关村',
#    '北京大学东门',
#    '圆明园',
#    '西苑',
#    '北宫门',
#    '安河桥北'],
#   '北京地铁5号线': ['宋家庄',
#    '刘家窑',
#    '蒲黄榆',
#    '天坛东门',
#    '磁器口',
#    '崇文门',
#    '东单',
#    '灯市口',
#    '东四',
#    '张自忠路',
#    '北新桥',
# ...

# %%
def subway_station_16(subway,url):
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        #print(i.find().text.strip())
        a = "车站名称往北安河方向往西苑方向"
        if i.find().text.strip() == a:#or i.find().text.strip() == a2:
            #print(i) 
            for tr in i.find_all('tr'):
                 #print(tr)
                if tr.find_all('th'):
                    for th in tr.find_all('th'):
                        #print(th)
                        if th.get('colspan') != '2' and th.get('colspan') != '3':
                            names = th.get_text()
                            if names not in ['车站名称','敷设方式','站厅形式','开门方向', '全程末班车时间','半程末班车时间','首车时间','末车时间']:
                                #print(names)
                                station_list.append(names)
                                city_subway_1[subway] = station_list
               
    return city_subway_1

# %%
subway_station_16('北京地铁16号线',station_web['北京地铁16号线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
def subway_station_batong(subway,url):
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a = subway[4:] + "首末车时刻表"
        if i.find().text.strip() == a:#or i.find().text.strip() == a2:
            #print(i) 
            for tr in i.find_all('tr'):
                 #print(tr)
                if tr.find_all('th'):
                    for th in tr.find_all('th'):
                        #print(th)
                        if th.get('colspan') != '2' and th.get('colspan') != '3':
                            names = th.get_text()
                            if names not in ['车站名称','敷设方式','站厅形式','开门方向', '全程末班车时间','半程末班车时间','首车时间']:
                                #print(names)
                                station_list.append(names)
                                city_subway_1[subway] = station_list
               
    return city_subway_1

# %%
subway_station_batong('北京地铁八通线',station_web['北京地铁八通线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
def subway_station_changping(subway,url):
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a = subway[4:] + "首末车时刻表"
        if i.find().text.strip() == a:#or i.find().text.strip() == a2:
            #print(i) 
            for tr in i.find_all('tr'):
                 #print(tr)
                if tr.find_all('th'):
                    for th in tr.find_all('th'):
                        #print(th)
                        if th.get('colspan') != '2' and th.get('colspan') != '3':
                            names = th.get_text()
                            if names not in ['车站名称','敷设方式','站厅形式','开门方向', '全程末班车时间','半程末班车时间','首车时间','']:
                                #print(names)
                                station_list.append(names)
                                city_subway_1[subway] = station_list
               
    return city_subway_1

# %%
subway_station_changping('北京地铁昌平线',station_web['北京地铁昌平线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
def subway_station_yizhuang(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a =  "车站信息"
#         print(i.find().text.strip() == a)
#         print(a)
        if i.find().text.strip() == a:
#             print(i) 
            for tr in i.find_all('tr'):
                #print(tr)
               for td in tr.find_all('td'):
                #print(td)
                if td.get('width') == "76":
                    #print(td)
                    station = td.get_text().replace('\n','')
                    if station != "亦庄火车站":
                        station = station.split('站')[0]
                    station_list.append(station)
                    city_subway_1[subway] = station_list
    return city_subway_1

# %%
subway_station_yizhuang('北京地铁亦庄线',station_web['北京地铁亦庄线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
def subway_station_fangshan(subway,url):
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a = subway[4:] + "首末车时刻表"
        if i.find().text.strip() == a:#or i.find().text.strip() == a2:
            #print(i) 
            for tr in i.find_all('tr'):
                 #print(tr)
                if tr.find_all('th'):
                    for th in tr.find_all('th'):
                        #print(th)
                        if th.get('colspan') != '2' and th.get('colspan') != '3':
                            names = th.get_text()
                            if names not in ['车站名称','敷设方式','站厅形式','开门方向', '全程末班车时间','半程末班车时间','首车时间','']:
                                #print(names)
                                station_list.append(names)
                                city_subway_1[subway] = station_list
               
    return city_subway_1

# %%
subway_station_fangshan('北京地铁房山线',station_web['北京地铁房山线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
def subway_station_S1(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a =  subway + "车站列表"
#         print(i.find().text.strip() == a)
#         print(a)
        if i.find().text.strip() == a:
#             print(i) 
            for tr in i.find_all('tr'):
                #print(tr)
               for td in tr.find_all('td'):
                #print(td)
                if td.get('width') == "100":
                    #print(td)
                    station = td.get_text().replace('\n','')
                    #if station != "亦庄火车站":
                    station = station.split('站')[0]
                    station_list.append(station)
                    city_subway_1[subway] = station_list
    return city_subway_1

# %%
subway_station_S1('北京地铁S1线',station_web['北京地铁S1线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
def subway_station_yanfang(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a = "车站名称往阎村东往燕山"
#         print(i.find().text.strip() == a)
#         print(a)
        if i.find().text.strip() == a:
#             print(i) 
            for tr in i.find_all('tr'):
                #print(tr)
               if tr.find_all('th'):
                    for th in tr.find_all('th'):
                        #print(th)
                        if th.get('width') == "184" :
                            names = th.get_text()
                            if names not in ['车站名称','敷设方式','站厅形式','开门方向', '全程末班车时间','半程末班车时间','首车时间','']:
                                #print(names)
                                station_list.append(names)
                                city_subway_1[subway] = station_list
               
    return city_subway_1

# %%
subway_station_yanfang('北京地铁燕房线',station_web['北京地铁燕房线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
def subway_station_daxing(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a =  subway + "车站信息"
#         print(i.find().text.strip() == a)
#         print(a)
        if i.find().text.strip() == a:
#             print(i) 
            for tr in i.find_all('tr'):
                #print(tr)
               for td in tr.find_all('td'):
                #print(td)
                if td.get('width') == "88":
                    #print(td)
                    station = td.get_text().replace('\n','')
                    if station != '黄村火车站':
                        station = station.split('站')[0]
                        if station in ['地下','整体式', '双岛式', '高架','侧式','右侧', '地下','岛式','左侧'] \
                        or station.startswith('['): continue
                    
                    station_list.append(station)
                    city_subway_1[subway] = station_list
                    city_subway[subway] = station_list
    return city_subway,city_subway_1

# %%
subway_station_daxing('北京地铁大兴线',station_web['北京地铁大兴线'])
# Out:
# ({'北京地铁1号线': ['苹果园',
#    '古城',
#    '八角游乐园',
#    '八宝山',
#    '玉泉路',
#    '五棵松',
#    '万寿路',
#    '公主坟',
#    '军事博物馆',
#    '木樨地',
#    '南礼士路',
#    '复兴门',
#    '西单',
#    '天安门西',
#    '天安门东',
#    '王府井',
#    '东单',
#    '建国门',
#    '永安里',
#    '国贸',
#    '大望路',
#    '四惠',
#    '四惠东'],
#   '北京地铁2号线': ['西直门',
#    '积水潭',
#    '鼓楼大街',
#    '安定门',
#    '雍和宫',
#    '东直门',
#    '东四十条',
#    '朝阳门',
#    '建国门',
#    '北京站',
#    '崇文门',
#    '前门',
#    '和平门',
#    '宣武门',
#    '长椿街',
#    '复兴门',
#    '阜成门',
#    '车公庄',
#    '西直门',
#    '西直门'],
#   '北京地铁4号线': ['公益西桥',
#    '角门西',
#    '马家堡',
#    '北京南站',
#    '陶然亭',
#    '菜市口',
#    '宣武门',
#    '西单',
#    '灵境胡同',
#    '西四',
#    '平安里',
#    '新街口',
#    '西直门',
#    '动物园',
#    '国家图书馆',
#    '魏公村',
#    '人民大学',
#    '海淀黄庄',
#    '中关村',
#    '北京大学东门',
#    '圆明园',
#    '西苑',
#    '北宫门',
#    '安河桥北'],
#   '北京地铁5号线': ['宋家庄',
#    '刘家窑',
#    '蒲黄榆',
#    '天坛东门',
#    '磁器口',
#    '崇文门',
#    '东单',
#    '灯市口',
#    '东四',
#    '张自忠路',
#    '北新桥',
# ...

# %%
def subway_station_jichang(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    for i in bsObj_1.find_all('table'):
        
        a = subway + "首末车时刻表"
#         print(i.find().text.strip() == a)
#         print(a)
        if i.find().text.strip() == a:
#             print(i) 
            for tr in i.find_all('tr'):
                #print(tr)
               if tr.find_all('th'):
                    for th in tr.find_all('th'):
                        #print(th)
                        if th.get('colspan') != "2":
                            names = th.get_text()
                            if names not in ['车站名称','敷设方式','站厅形式','开门方向', '全程末班车时间','半程末班车时间','首车时间','','备注']:
                                #print(names)
                                if names == '东直门站':
                                    names = names.split('站')[0]
                                station_list.append(names)
                                city_subway_1[subway] = station_list
               
    return city_subway_1

# %%
subway_station_jichang('北京地铁机场线',station_web['北京地铁机场线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
def subway_station_xijiao(subway,url):
    
    station_list = []
    bsObj_1 = BeautifulSoup(urlopen(url).read())
    i  = bsObj_1.find_all('table')[0]
        
#         a = "编号车站名称所属区段开通日期可换乘线路站台形式"
#     print(i)
# #         print(a)
#     if i.find().text.strip() == a:
# #             print(i) 
    for tr in i.find_all('tr'):
        #print(tr)
        for td in tr.find_all('td'):
        #print(td)
            if td.get('width') == "81" and td.get('colspan') != "1":
                #print(td)
                station = td.get_text().replace('\n','')
                if station in [ '北京地铁10号线(出站换乘）']: continue
                #if station != "亦庄火车站":
                station = station.split('站')[0] 
                station_list.append(station)
                city_subway_1[subway] = station_list
    return city_subway_1

# %%
subway_station_xijiao('北京地铁西郊线',station_web['北京地铁西郊线'])
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
city_subway ##1,2,4,5,6,10,15号线
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
import pandas as pd
file = 'station1.csv'
station_zuobiao = pd.read_csv(file,encoding='gb18030')
station_zuobiao.head()
# Out:
#   station        pat        long
# 0     苹果园  39.926325  116.177781
# 1      古城  39.907201  116.190248
# 2   八角游乐园  39.907432  116.212821
# 3     八宝山  39.907267  116.235824
# 4     玉泉路  39.907333  116.253033

# %%
station_long_lat = {}
for i in range(len(station_zuobiao['station'].tolist())):
    #if i < 23:
    name = station_zuobiao['station'].tolist()[i]
    long,lat = station_zuobiao['long'].tolist()[i],station_zuobiao['pat'].tolist()[i]
    station_long_lat[name] = (long,lat)

# %%
'平西府' in station_long_lat.keys()
# Out:
# False

# %% [markdown]
# ## 以1,2,4,5,6,10,15号线为例子

# %%
#station_name1= []
##1,2,4,5,6,10,15号线
station_line = []
for i,f in city_subway.items():
    for x,y in enumerate(f):
        #print(y)

        if x != len(f) - 1:
            station_line.append((y,f[x+1]))
print(station_line)
        
    #print(f)
#     station_name1 += f
# one_line = station_name1[:23]
#     #sorted(station_name1)
# # print(len(one_line))
# Out:
# [('苹果园', '古城'), ('古城', '八角游乐园'), ('八角游乐园', '八宝山'), ('八宝山', '玉泉路'), ('玉泉路', '五棵松'), ('五棵松', '万寿路'), ('万寿路', '公主坟'), ('公主坟', '军事博物馆'), ('军事博物馆', '木樨地'), ('木樨地', '南礼士路'), ('南礼士路', '复兴门'), ('复兴门', '西单'), ('西单', '天安门西'), ('天安门西', '天安门东'), ('天安门东', '王府井'), ('王府井', '东单'), ('东单', '建国门'), ('建国门', '永安里'), ('永安里', '国贸'), ('国贸', '大望路'), ('大望路', '四惠'), ('四惠', '四惠东'), ('西直门', '积水潭'), ('积水潭', '鼓楼大街'), ('鼓楼大街', '安定门'), ('安定门', '雍和宫'), ('雍和宫', '东直门'), ('东直门', '东四十条'), ('东四十条', '朝阳门'), ('朝阳门', '建国门'), ('建国门', '北京站'), ('北京站', '崇文门'), ('崇文门', '前门'), ('前门', '和平门'), ('和平门', '宣武门'), ('宣武门', '长椿街'), ('长椿街', '复兴门'), ('复兴门', '阜成门'), ('阜成门', '车公庄'), ('车公庄', '西直门'), ('西直门', '西直门'), ('公益西桥', '角门西'), ('角门西', '马家堡'), ('马家堡', '北京南站'), ('北京南站', '陶然亭'), ('陶然亭', '菜市口'), ('菜市口', '宣武门'), ('宣武门', '西单'), ('西单', '灵境胡同'), ('灵境胡同', '西四'), ('西四', '平安里'), ('平安里', '新街口'), ('新街口', '西直门'), ('西直门', '动物园'), ('动物园', '国家图书馆'), ('国家图书馆', '魏公村'), ('魏公村', '人民大学'), ('人民大学', '海淀黄庄'), ('海淀黄庄', '中关村'), ('中关村', '北京大学东门'), ('北京大学东门', '圆明园'), 
# ...

# %%
station_line.append(('新宫','公益西桥'))

# %%
# station_line = []
# for i,f in enumerate(one_line):
#     if i != len(one_line) - 1:
#         station_line.append((f,one_line[i+1]))
# print(station_line)

# %%
import networkx as nx

# %%
city_graph = nx.Graph()
city_graph.add_nodes_from(list(station_long_lat.keys()))
city_graph.add_edges_from(station_line)

# %%
# %matplotlib inline

# %%
nx.draw(city_graph,station_long_lat,with_labels= False,node_size=10)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# 如果a在一条线上，a可以到达这条线的所有站，建一个字典，a作为key，他所在的地铁线为value
# 定义一个换乘站，1.如果开始地点是换乘站，那么寻找在该换乘站上经过的所有线路，如果目的地在这些线路上，返回开始地点到目的地点之间的所有站名
# 2.如果开始地点不是换乘站，那么找到他所在的这条线路上离开始地点最近的换乘站，然后重复第一步，如果没有目的地，则查找下一个换乘站，直到找到目的地，返回开始到换乘站和换乘站到目的地之间的所有站名。

# %% [markdown]
# ##怎么定义换乘站？
# 换乘站表示，这个站名在至少两条线上出现。

# %%
city_subway_1##所有线路
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁2号线': ['西直门',
#   '积水潭',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '北京站',
#   '崇文门',
#   '前门',
#   '和平门',
#   '宣武门',
#   '长椿街',
#   '复兴门',
#   '阜成门',
#   '车公庄',
#   '西直门',
#   '西直门'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
# ...

# %%
##将每个站可以到达的地点放到一个列表中，组成一个字典
transform_station1 = {}
station_k = [] #记录所有线路名
station_v = [] # 记录所有站名
##所有站名
for i in city_subway_1.values():
    for x in i:
        station_v.append(x)
#所有线
for line in city_subway_1.keys():
    station_k.append(line) 
  
for station_name in station_v:
#     print(a)
#     print(a in city_subway)
    stations = []
    for station_line in station_k:
        if station_name not in city_subway_1[station_line]:continue
        for x in city_subway_1[station_line]:
            if station_name == x: continue
            stations.append(x)
        #print(stations)
        #if len(sorted(stations)) > 1:
            transform_station1[station_name] = stations

# %%
transform_station1
# Out:
# {'苹果园': ['古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东',
#   '金安桥',
#   '杨庄',
#   '西黄村',
#   '廖公庄',
#   '田村',
#   '海淀五路居',
#   '慈寿寺',
#   '花园桥',
#   '白石桥南',
#   '车公庄西',
#   '车公庄',
#   '平安里',
#   '北海北',
#   '南锣鼓巷',
#   '东四',
#   '朝阳门',
#   '东大桥',
#   '呼家楼',
#   '金台路',
#   '十里堡',
#   '青年路',
#   '褡裢坡',
#   '黄渠',
#   '常营',
#   '草房',
#   '物资学院路',
#   '通州北关',
#   '北运河西',
#   '北运河东',
#   '郝家府',
#   '东夏园',
#   '潞城',
#   '金安桥',
#   '四道桥',
#   '桥户营',
#   '上岸',
#   '栗园庄',
#   '小园',
#   '石厂'],
#  '古城': ['苹果园',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '八角游乐园': ['苹果园',
#   '古城',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
# ...

# %%
city_subway_1
# Out:
# {'北京地铁1号线': ['苹果园',
#   '古城',
#   '八角游乐园',
#   '八宝山',
#   '玉泉路',
#   '五棵松',
#   '万寿路',
#   '公主坟',
#   '军事博物馆',
#   '木樨地',
#   '南礼士路',
#   '复兴门',
#   '西单',
#   '天安门西',
#   '天安门东',
#   '王府井',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  '北京地铁4号线': ['公益西桥',
#   '角门西',
#   '马家堡',
#   '北京南站',
#   '陶然亭',
#   '菜市口',
#   '宣武门',
#   '西单',
#   '灵境胡同',
#   '西四',
#   '平安里',
#   '新街口',
#   '西直门',
#   '动物园',
#   '国家图书馆',
#   '魏公村',
#   '人民大学',
#   '海淀黄庄',
#   '中关村',
#   '北京大学东门',
#   '圆明园',
#   '西苑',
#   '北宫门',
#   '安河桥北'],
#  '北京地铁5号线': ['宋家庄',
#   '刘家窑',
#   '蒲黄榆',
#   '天坛东门',
#   '磁器口',
#   '崇文门',
#   '东单',
#   '灯市口',
#   '东四',
#   '张自忠路',
#   '北新桥',
#   '雍和宫',
#   '和平里北街',
#   '和平西桥',
#   '惠新西街南口',
#   '惠新西街北口',
#   '大屯路东',
#   '北苑路北',
#   '立水桥南',
#   '立水桥',
#   '天通苑南',
#   '天通苑',
#   '天通苑北'],
#  '北京地铁6号线': ['金安桥',
#   '苹果园',
#   '杨庄',
#   '西黄村',
#   '廖公庄',
#   '田村',
#   '海淀五路居',
#   '慈寿寺',
#   '花园桥',
#   '白石桥南',
#   '车公庄西',
#   '车公庄',
#   '平安里',
#   '北海北',
# ...

# %%
from collections import defaultdict

# %%
##根据线路将每个站点连接起来
transform_station = defaultdict(list)
for line,name_list in city_subway_1.items():
    #print(len(name_list))
    for x,f in enumerate(name_list):
        
        if f not in transform_station:
             
            if x == 0:
                transform_station[f] = [name_list[x+1]]
            elif x == len(name_list) -1: 
                transform_station[f] = [name_list[x-1]]
            else:
                transform_station[f] = [name_list[x-1],name_list[x+1]]
        else:
            if x == 0:
                transform_station[f] +=[name_list[x+1]]
            elif x == len(name_list) -1: 
                transform_station[f] += [name_list[x-1]]
            else:
                transform_station[f] += [name_list[x-1],name_list[x+1]]

# %%
transform_station
# Out:
# defaultdict(list,
#             {'苹果园': ['古城', '金安桥', '杨庄', '金安桥'],
#              '古城': ['苹果园', '八角游乐园'],
#              '八角游乐园': ['古城', '八宝山'],
#              '八宝山': ['八角游乐园', '玉泉路'],
#              '玉泉路': ['八宝山', '五棵松'],
#              '五棵松': ['玉泉路', '万寿路'],
#              '万寿路': ['五棵松', '公主坟'],
#              '公主坟': ['万寿路', '军事博物馆', '莲花桥', '西钓鱼台'],
#              '军事博物馆': ['公主坟', '木樨地', '北京西站', '白堆子'],
#              '木樨地': ['军事博物馆', '南礼士路'],
#              '南礼士路': ['木樨地', '复兴门'],
#              '复兴门': ['南礼士路', '西单', '长椿街', '阜成门'],
#              '西单': ['复兴门', '天安门西', '宣武门', '灵境胡同'],
#              '天安门西': ['西单', '天安门东'],
#              '天安门东': ['天安门西', '王府井'],
#              '王府井': ['天安门东', '东单'],
#              '东单': ['王府井', '建国门', '崇文门', '灯市口'],
#              '建国门': ['东单', '永安里', '朝阳门', '北京站'],
#              '永安里': ['建国门', '国贸'],
#              '国贸': ['永安里', '大望路', '金台夕照', '双井'],
#              '大望路': ['国贸', '四惠', '九龙山', '金台路'],
#              '四惠': ['大望路', '四惠东', '四惠东'],
# ...

# %%
##返回的是换乘点
##怎么返回全部站点？？？已解决

def search(start,distation,transfrom_station): ##transform_station为连接点
    pathes = [[start]]
    visited = set()
    
    while pathes:
        path = pathes.pop(0)
        froninter = path[-1]
        
        if froninter in visited: continue
        
        successor = transfrom_station[froninter]
        for subway in successor:
            if subway in path: continue
            new_path = path + [subway]
            pathes.append(new_path)
                
            if subway == distation: return new_path
        visited.add(froninter)
            

    
#     s_d_station = []
#     if start in transform_station.keys():
#         line_station = []
#         line_station = transform_station[start]
#         if distation in subway[[a for a in line_station]]:
#             start_index = subway[a].index(start)
#             dis_index = subway[a].index(distation)
#             if start_index > dis_index:
#                 s_d_station.append(subway[a][dis_index:start_index + 1])
#                 s_d_station = list(reverse(s_d_station))
#             else:
#                 s_d_station.append(subway[a][start_index:dis_index + 1])
        
#         else: 
#             start = distation

# %%
sta = search('国家图书馆','天安门西',transform_station)

# %%
print('=>'.join(sta))
# Out:
# 国家图书馆=>动物园=>西直门=>车公庄=>阜成门=>复兴门=>西单=>天安门西

# %% [markdown]
# ##### 2.	Preprocessing data from page source.
#
# > a.	Based on the page source gotten from url. You may need some more preprocessing of the page.
#
# > b.	the Regular Expression you may need to process the text information.
#
# > c.	You may need @package networkx, @package matplotlib to visualize data.
#
# > d.	You should build a dictionary or graph which could represent the connection information of Beijing subway routes.
#
# > e.	You may need the defaultdict, set data structures to implement this procedure.

# %% [markdown]
# ##### 3. Build the search agent
#
# > Build the search agent based on the graph we build.
#
# for example, when you run:
#
# ```python
# >>> search('奥体中心', '天安门')
# ```
# you need get the result:
#
# 奥体中心-> A -> B -> C -> ... -> 天安门

# %% [markdown]
# ## （Optional）Create different policies for transfer system.

# %% [markdown]
# 以下部门为可选部分，请酌情完成。 并不要求全部同学完成。

# %% [markdown]
# As much as you can to use the already implemented search agent. You just need to define the **is_goal()**, **get_successor()**, **strategy()** three functions.
#
# > a.	Define different policies for transfer system.
#
# > b.	Such as Shortest Path Priority（路程最短优先）, Minimum Transfer Priority(最少换乘优先), Comprehensive Priority(综合优先)
#
# > c.	Implement Continuous transfer. Based on the Agent you implemented, please add this feature: Besides the @param start and @param destination two stations, add some more stations, we called @param by_way, it means, our path should from the start and end, but also include the  @param by_way stations.
#
# e.g
# ```
# 1. Input:  start=A,  destination=B, by_way=[C]
#     Output: [A, … .., C, …. B]
# 2. Input: start=A, destination=B, by_way=[C, D, E]
#     Output: [A … C … E … D … B]
#     # based on your policy, the E station could be reached firstly.
# ![image.png](attachment:image.png)
# ```

# %% [markdown]
# ##### 5.	Test your result with commercial applications.
#
# 将你的结果和高德地图或者百度地图进行比较，如果有不同，请分析原因

# %% [markdown]
# 恭喜，完成本次课程，你对常用的人工智能方法以及有一定的了解了。基于规则的，基于概率模型的，基于搜索的，基于机器学习的。 可以说，我们现在通常见到的方法都能够归属到这几类方法中。 这就是**人工智能**，并没有很难是吧？ 继续加油！

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1562415163815&di=4b29a2a863a8285212033760f288ed7a&imgtype=0&src=http%3A%2F%2F5b0988e595225.cdn.sohucs.com%2Fimages%2F20180710%2F8704194a1d7f46a383ddc29d40c9bca5.jpeg)
